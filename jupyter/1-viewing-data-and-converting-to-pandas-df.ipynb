# %%
import pandas as pd
import numpy as np
import json
import re

# %%
testData = pd.DataFrame()
for i in [1,2,4,5,6]:
    data = pd.read_json('../data/cleanQuestionList-{}.json'.format(str(i)))
    data['file'] = i
    testData = testData.append(data, ignore_index=True)
    
copyData = testData.copy()

# %% [markdown]
# # Clean dataframe

# %%
print('length of df: ', len(copyData))
copyData = copyData.replace(r'^\s*$', np.nan, regex=True)
copyData.describe()
# Out:
# length of df:  20036
#             qNumber  answerNumber          file
# count  20031.000000  19816.000000  20036.000000
# mean    2454.159403      3.003482      3.707327
# std     1462.581896      1.355855      1.679272
# min        1.000000      1.000000      1.000000
# 25%     1252.500000      2.000000      2.000000
# 50%     2354.000000      3.000000      4.000000
# 75%     3545.500000      4.000000      5.000000
# max     5684.000000      5.000000      6.000000

# %%
## missing data
for column in copyData.columns:
    print(column, len(copyData.loc[copyData[column].isnull()]))
# Out:
# questionDescription 3684
# question 156
# options 156
# answer 5
# qNumber 5
# qOrigin 5
# qTopic 156
# answerNumber 220
# answerDescription 220
# file 0

# %%
# we need to remove those rows where question, options and answerNumber is null
copyData = copyData[copyData.question.notna() & 
                    copyData.options.notna() &
                    copyData.answerNumber.notna()
                   ]

# %%
## missing data
for column in copyData.columns:
    print(column, len(copyData.loc[copyData[column].isnull()]))
# Out:
# questionDescription 3655
# question 0
# options 0
# answer 0
# qNumber 0
# qOrigin 0
# qTopic 0
# answerNumber 0
# answerDescription 0
# file 0

# %%
copyData.sample(4)
# Out:
#                                      questionDescription  \
# 16276  A 38 year old male with known alcohol excess p...
# 18028  A 65 year old lady has epigastric pain for sev...
# 7733   A 19-year-old student nurse was admitted after...
# 8350   A young woman with known systemic lupus erythe...
#
#                                                 question  \
# 16276                  What else would you do initially?
# 18028  Which one of the following associations for He...
# 7733   What diagnosis fits best with this clinical pi...
# 8350             Which agent best fits her requirements?
#
#                                                  options  \
# 16276  {'1': 'IV antibiotics', '2': 'IV terlipressin ...
# 18028  {'1': 'Gastro oesophageal reflux disease', '2'...
# 7733   {'1': 'Insulinoma', '2': 'Glucagonoma', '3': '...
# 8350   {'1': 'Mycophenolate mofetil', '2': 'Sirolimus...
#
#                                                   answer  qNumber  \
# 16276   Answer & Comments Answer: 2- IV terlipressin ...   3532.0
# 18028   Answer & Comments Answer: 2- Non ulcer formin...   1992.0
# 7733    Answer & Comments Answer: 4- Self-administrat...    674.0
# 8350    Answer & Comments Answer: 1- Mycophenolate mo...   1291.0
#
#             qOrigin          qTopic  answerNumber  \
# 16276    ReviseMRCP  2012 September           2.0
# 18028       MRCPass  2010 September           2.0
# 7733   PasTest 2009   Endocrinology           4.0
# 8350   PasTest 2009   Basic Science           1.0
#
#                                        answerDescription  file
# 16276   Answer & Comments Answer: 2- IV terlipressin ...     5
# 18028   Answer & Comments Answer: 2- Non ulcer formin...     6
# 7733    Answer & Comments Answer: 4- Self-administrat...     4
# 8350    Answer & Comments Answer: 1- Mycophenolate mo...     4

# %%
# remove duplicates

# %%
droppedDuplicate = copyData.drop_duplicates(subset=
    ['questionDescription', 'question']
)
len(droppedDuplicate)
# droppedDuplicate.questionDescription.value_counts()
# Out:
# 14186

# %%
droppedDuplicate.qTopic.value_counts()
# Out:
# Endocrinology            1286
# Basic Science            1241
# Cardiology               1120
# Neurology                1009
# Rheumatology              952
# Respiratory               952
# Gastroenterology          925
# Haematology               912
# Nephrology                791
# Infectious disease        692
# Clinical pharmacology     664
# Psychiatry                469
# Dermatology               363
# Statistics                261
# Ophthalmology             201
# 2012 January              158
# 2011 January              150
# 2011 September            148
# 2010 September            139
# 2011 May                  139
# General revision          136
# Misc                      132
# Tropical medicine         119
# 2010 May                  116
# Emergency medicine        111
# 2009 January              109
# 2010 January              106
# Pharmacology               98
# 2009 May                   96
# 2006 May                   83
# 2008 January               63
# Emergency Medicine         54
# 2013 January               49
# 2008 September             49
# 2 Mock exam                48
# Medicine                   46
# 2 exam                     41
# 2006 January               38
# 2007 September             37
# 2012 September             29
# 2012 May                   28
# Ethics and law             26
# Name: qTopic, dtype: int64

# %%
def returnPastPaper(inputStr):
    if inputStr[0]=='2':
        return 'Past paper'
    else:
        return inputStr

droppedDuplicate.loc[:, 'qTopic'] = droppedDuplicate.loc[:, 'qTopic'].apply(lambda x: returnPastPaper(x))
droppedDuplicate.loc[droppedDuplicate['qTopic']=='Clinicalpharmacology', 'qTopic']='Clinical pharmacology'
droppedDuplicate.loc[droppedDuplicate['qTopic']=='Infectiousdisease', 'qTopic']='Infectious disease'
droppedDuplicate.loc[droppedDuplicate['qTopic']=='Tropicalmedicine', 'qTopic']='Tropical medicine'

# %%
for option in ['option1','option2','option3','option4','option5']:
    number = option[-1]
    droppedDuplicate.loc[:,option] = droppedDuplicate.loc[:, 'options'].apply(lambda x: x[number])

# %%
droppedDuplicate.sample(4)
# Out:
#                                      questionDescription  \
# 18383  A 26 year old lady presents with abdominal pai...
# 7835   A sexually active 19-year-old Nigerian man pre...
# 8997   A 72-year-old woman with metastatic carcinoma ...
# 4784   A 29-year-old woman is admitted for investigat...
#
#                                                 question  \
# 18383                      What is the likely diagnosis?
# 7835                  What is the most likely diagnosis?
# 8997   Which of the following would be the most appro...
# 4784   Which of the following is the next most approp...
#
#                                                  options  \
# 18383  {'1': 'Multiple myeloma', '2': 'Renal tubular ...
# 7835   {'1': 'Herpes simplex virus', '2': 'Lymphogran...
# 8997   {'1': 'Reduce her MST and add naproxen', '2': ...
# 4784   {'1': '72 hour supervised fast', '2': 'CT abdo...
#
#                                                   answer  qNumber  \
# 18383   Answer & Comments Answer: 2- Renal tubular ac...   2163.0
# 7835    Answer & Comments Answer: 1- Herpes simplex v...    776.0
# 8997    Answer & Comments Answer: 4- Keep her MST sta...   1938.0
# 4784    Answer & Comments Answer: 1- 72 hour supervis...   2309.0
#
#                   qOrigin                 qTopic  answerNumber  \
# 18383             MRCPass             Past paper           2.0
# 7835         PasTest 2009     Infectious disease           1.0
# 8997         PasTest 2009  Clinical pharmacology           4.0
# 4784   OnExamination 2012          Endocrinology           1.0
#
#                                        answerDescription  file  \
# 18383   Answer & Comments Answer: 2- Renal tubular ac...     6
# 7835    Answer & Comments Answer: 1- Herpes simplex v...     4
# 8997    Answer & Comments Answer: 4- Keep her MST sta...     4
# 4784    Answer & Comments Answer: 1- 72 hour supervis...     2
#
#                                option1  \
# 18383                 Multiple myeloma
# 7835              Herpes simplex virus
# 8997   Reduce her MST and add naproxen
# 4784           72 hour supervised fast
#
#                                               option2  \
# 18383                   Renal tubular acidosis type 1
# 7835                         Lymphogranuloma venereum
# 8997   Keep her MST stable and stop her oral morphine
# 4784                                       CT abdomen
#
#                                option3  \
# 18383               Nephrotic syndrome
# 7835                          Syphilis
# 8997   Stop her MST and start naproxen
# 4784                    Pancreatic USS
#
#                                                  option4  \
# 18383                                     Homocystinuria
# 7835                                           Chancroid
# 8997   Keep her MST stable, reduce her oral morphine ...
# 4784                              Proinsulin measurement
#
#                                             option5
# 18383                                     Porphyria
# 7835     Granuloma inguinale Part 1 ) – 2013    359
# 8997   Transfer her pain relief to fentanyl patches
# 4784                      Urine sulphonylurea assay

# %% [markdown]
# # explore data set
#
# ## need to look for duplicates!

# %%
exploreDataSet = droppedDuplicate.copy().reset_index().set_index('index')

# %%
exploreDataSet.describe()
# Out:
#             qNumber  answerNumber          file
# count  14186.000000  14186.000000  14186.000000
# mean    2042.849359      3.013887      3.105809
# std     1396.291278      1.347912      1.487397
# min        1.000000      1.000000      1.000000
# 25%      906.000000      2.000000      2.000000
# 50%     1825.000000      3.000000      4.000000
# 75%     3017.750000      4.000000      4.000000
# max     5684.000000      5.000000      6.000000

# %%
exploreDataSet.head(10)
# Out:
#                                      questionDescription  \
# index
# 1      A 45 year old man presents with acute, profuse...
# 2      A 45 year old man has had long standing jaundi...
# 3      A 72 year old woman with longstanding hip oste...
# 4      A 40 year old man has symptoms of lethargy, jo...
# 5      A 50 year old patient has a 2 year history of ...
# 6      A 45 year old man has returned from holiday in...
# 7      A 22 year old man has recently returned from I...
# 8      A 60 year old woman presents with diarrhoea. S...
# 9      A 60 year old man has a 5 day history of abdom...
# 10     A 50 year old man has diabetes. He has the fol...
#
#                                                 question  \
# index
# 1      Which one of the following is the most appropr...
# 2                          What is the likely diagnosis?
# 3                         What is the most likely cause?
# 4                    What is the recommended management?
# 5      Which one of the following is a feature of VIP...
# 6                          What is the likely diagnosis?
# 7      Which of the following investigations would be...
# 8                          What is the likely diagnosis?
# 9      Which of the following is most likely to confi...
# 10     Which one of the following is an appropriate i...
#
#                                                  options  \
# index
# 1      {'1': 'Metronidazole', '2': 'Ciprofloxacin', '...
# 2      {'1': 'Abnormal variant hepatitis C', '2': 'Su...
# 3      {'1': 'Non-steroidal anti-inflammatory drugs',...
# 4      {'1': 'Venesection', '2': 'Haemodialysis', '3'...
# 5      {'1': 'Hypoglycaemia', '2': 'Hypokalaemia', '3...
# 6      {'1': 'Campylobacter infection', '2': 'Coeliac...
# 7      {'1': 'Ultrasound scan of abdomen', '2': 'Anti...
# 8      {'1': 'Radiation enteropathy', '2': 'Coeliac d...
# 9      {'1': 'CT scan of the abdomen', '2': 'Amoxycil...
# 10     {'1': 'Transferrin saturation', '2': 'Serum el...
#
#                                                   answer  qNumber  qOrigin  \
# index
# 1       Answer & Comments Answer: 2- Ciprofloxacin Th...      1.0  MRCPass
# 2       Answer & Comments Answer: 3- Hepatocellular c...      2.0  MRCPass
# 3       Answer & Comments Answer: 5- Laxative abuse T...      3.0  MRCPass
# 4       Answer & Comments Answer: 1- Venesection In h...      4.0  MRCPass
# 5       Answer & Comments Answer: 2- Hypokalaemia VIP...      5.0  MRCPass
# 6       Answer & Comments Answer: 1- Campylobacter in...      6.0  MRCPass
# 7       Answer & Comments Answer: 1- Ultrasound scan ...      7.0  MRCPass
# 8       Answer & Comments Answer: 2- Coeliac disease ...      8.0  MRCPass
# 9       Answer & Comments Answer: 3- Stool sample for...      9.0  MRCPass
# 10      Answer & Comments Answer: 1- Transferrin satu...     10.0  MRCPass
#
#                  qTopic  answerNumber  \
# index
# 1      Gastroenterology           2.0
# 2      Gastroenterology           3.0
# 3      Gastroenterology           5.0
# 4      Gastroenterology           1.0
# 5      Gastroenterology           2.0
# 6      Gastroenterology           1.0
# 7      Gastroenterology           1.0
# 8      Gastroenterology           2.0
# 9      Gastroenterology           3.0
# 10     Gastroenterology           1.0
#
#                                        answerDescription  file  \
# index
# 1       Answer & Comments Answer: 2- Ciprofloxacin Th...     1
# 2       Answer & Comments Answer: 3- Hepatocellular c...     1
# 3       Answer & Comments Answer: 5- Laxative abuse T...     1
# 4       Answer & Comments Answer: 1- Venesection In h...     1
# 5       Answer & Comments Answer: 2- Hypokalaemia VIP...     1
# 6       Answer & Comments Answer: 1- Campylobacter in...     1
# 7       Answer & Comments Answer: 1- Ultrasound scan ...     1
# 8       Answer & Comments Answer: 2- Coeliac disease ...     1
# 9       Answer & Comments Answer: 3- Stool sample for...     1
# 10      Answer & Comments Answer: 1- Transferrin satu...     1
#
#                                      option1  \
# index
# 1                              Metronidazole
# 2               Abnormal variant hepatitis C
# 3      Non-steroidal anti-inflammatory drugs
# 4                                Venesection
# 5                              Hypoglycaemia
# 6                    Campylobacter infection
# 7                 Ultrasound scan of abdomen
# 8                      Radiation enteropathy
# 9                     CT scan of the abdomen
# 10                    Transferrin saturation
#
#                                   option2  \
# index
# 1                           Ciprofloxacin
# 2      Superimposed hepatitis E infection
# 3                         Crohn's disease
# 4                           Haemodialysis
# 5                            Hypokalaemia
# 6                         Coeliac disease
# 7                Anti endomysial antibody
# 8                         Coeliac disease
# 9           Amoxycillin and metronidazole
# 10                  Serum electrophoresis
#
#                                         option3  \
# index
# 1                                    Vancomycin
# 2                      Hepatocellular carcinoma
# 3                          Diverticular disease
# 4                              Liver transplant
# 5      Induction of VIP release by somatostatin
# 6                                  Tuberculosis
# 7                              Typhoid serology
# 8                             Ischaemic colitis
# 9                  Stool sample for E coli 0157
# 10                  Serum transferrin receptors
#
#                                                  option4  \
# index
# 1                                           Prednisolone
# 2                                  Hepatitis A infection
# 3                                      Whipple's disease
# 4                                       Phenoxybenzamine
# 5                                                Anaemia
# 6                                     Ulcerative colitis
# 7                         Stool for ova, cysts parasites
# 8                                        Crohn's disease
# 9      Mesenteric angiography to exclude ischaemic co...
# 10                                          Liver biopsy
#
#                                  option5
# index
# 1                             Cefuroxime
# 2               Infectious mononucleosis
# 3                         Laxative abuse
# 4                               Glucagon
# 5      Increased gastric acid seceretion
# 6                      Gonococcal sepsis
# 7                           Colonosocopy
# 8                         Tropical Sprue
# 9                    Surgical laparotomy
# 10                           Urinary PBG

# %%
exploreDataSet.columns
# Out:
# Index(['questionDescription', 'question', 'options', 'answer', 'qNumber',
#        'qOrigin', 'qTopic', 'answerNumber', 'answerDescription', 'file',
#        'option1', 'option2', 'option3', 'option4', 'option5'],
#       dtype='object')

# %%
slimDataSet = exploreDataSet[[
    'questionDescription', 'question', 'qTopic', 'option1', 'option2', 
    'option3', 'option4', 'option5', 'answerNumber']]

# %%
exploreDataSet.to_csv('../data/full-cleaned-pandas-ready-data-set.csv')
slimDataSet.to_csv('../data/slim-cleaned-pandas-ready-data-set.csv')
